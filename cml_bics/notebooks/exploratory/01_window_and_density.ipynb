# %% [markdown]
# # 01 — Window construction and density screen

# %%
import pandas as pd, numpy as np
p = pd.read_parquet('../data/processed/master_panel/panel_v3_full.parquet')
p.shape

# %%
w = p[(p.risk_score>60)&(p.risk_score<90)]
w.groupby((w.risk_score>=75).astype(int))['enrolled_d'].mean()
